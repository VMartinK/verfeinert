# %% [markdown]
# # CX-01 Reproduction
#
# Researcher-facing workflow for the CX-01 reproduction profile.

# %%
from pathlib import Path
import sys

EXAMPLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(EXAMPLE_ROOT / 'scripts'))

from run_cx01_reproduction import DEFAULT_CONFIG_PATH, load_config, run_reproduction

config = load_config(DEFAULT_CONFIG_PATH)
config['cx01_campaign']

# %%
result = run_reproduction(DEFAULT_CONFIG_PATH, profile='smoke')
result.to_dict()

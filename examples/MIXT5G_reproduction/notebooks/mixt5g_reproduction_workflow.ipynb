# %% [markdown]
# # MIXT-5G Reproduction
#
# Researcher-facing workflow for the bounded MIXT-5G reproduction profile.

# %%
from pathlib import Path
import sys

EXAMPLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(EXAMPLE_ROOT / 'scripts'))

from run_mixt5g_reproduction import DEFAULT_CONFIG_PATH, load_config, run_reproduction

config = load_config(DEFAULT_CONFIG_PATH)
config['mixt5g_campaign']['mutation_schedule']

# %%
result = run_reproduction(DEFAULT_CONFIG_PATH, profile='smoke')
result.to_dict()
